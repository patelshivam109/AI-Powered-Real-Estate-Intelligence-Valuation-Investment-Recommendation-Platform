# %%
import numpy as np

y_pred_log = catboost_log_model.predict(X_test)

y_pred = np.expm1(y_pred_log)

y_actual = np.expm1(y_test)

print(y_pred[:5])
print(y_actual[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
# ----> 3 y_pred_log = catboost_log_model.predict(X_test)
#       5 y_pred = np.expm1(y_pred_log)
#       7 y_actual = np.expm1(y_test)
#
# NameError: name 'catboost_log_model' is not defined
